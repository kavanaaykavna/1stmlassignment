# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kavanaaykavna/1stmlassignment/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ML Task Type: Classification
# I frame my lane as a binary classification problem because the goal is to predict whether a webpage is likely to decline in search performance or not decline based on its historical SEO metrics. Each webpage is classified into one of two categories using features such as impressions, CTR, average position, content age, and days since the last update. The predicted probability can then be used to rank pages so that the SEO team can prioritize which ones to review first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target: The target is whether a webpage is declining or not declining in search performance. In the starter dataset, this is represented by the label is_declining_label, which is created from the trend_direction column.
# Where does the label come from?
# The label comes from an observed outcome, not from a prediction. It is created using a defined rule based on historical performance: if trend_direction = "down", then is_declining_label = 1 (declining); otherwise, is_declining_label = 0 (not declining). This means the model learns from what actually happened in the past and uses those examples to predict whether new webpages are likely to decline.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success Metric: Precision@50 I will use Precision@50 as the primary success metric because the SEO team can review only a limited number of webpages at a time. Precision@50 measures the proportion of the top 50 pages recommended by the model that are actually declining. A higher Precision@50 means the model is better at identifying pages that truly need attention, helping the team use its time and resources more effectively. What number means "good"? A good model should achieve a higher Precision@50 than a simple hand-written rule or baseline. In the starter notebook, the learned model is compared against a hand rule, so improvement over that baseline demonstrates that the model is adding value. Generally, the closer Precision@50 is to 1.0 (100%), the better the model is at recommending the right pages for review.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row represents one webpage (content page). Each row contains historical SEO and engagement metrics for a single webpage, such as impressions, click-through rate (CTR), average search position, content age, word count, and trend information. These features are used to predict whether the webpage is likely to experience declining search performance and should be prioritized for a content refresh.

# %%
import pandas as pd




df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (28060, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Machine learning is more suitable than a fixed rule because webpage performance depends on the interaction of many factors, not just one condition. Metrics such as impressions, CTR, average position, content age, days since the last update, and word count all influence whether a page is likely to decline. A simple if-statement like "if impressions < 500, then decline" cannot capture these complex relationships and may miss important patterns. A machine learning model can learn how multiple features work together from historical data and make more accurate predictions, while still allowing the SEO team to review the final recommendations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self-check
#
# - ✅ Every section above is filled, including both markdown explanations and supporting code.
# - ✅ The notebook runs from top to bottom without errors (Runtime → Run all).
# - ✅ No client names, URLs, or private search queries are included.
# - ✅ My claims use careful language such as "observed", "measured", "directional", and "decision-support" instead of making causal claims.
# - ✅ The notebook has been committed to my GitHub repository under `work/notebooks/` and I will submit my repository URL.
