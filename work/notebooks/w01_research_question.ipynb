# %% [markdown]
# <a href="https://colab.research.google.com/github/kavanaaykavna/1stmlassignment/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kavanaaykavna/1stmlassignment/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane
# Refresh / Content Opportunity Scoring
# Why I chose this lane
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that are likely to decline in search performance and should be reviewed first. The goal is not simply to classify pages as declining or not declining, but to help SEO teams prioritize limited time and resources by ranking pages based on their need for content updates. This lane also matches the provided starter dataset and allows me to build on the existing baseline before exploring more advanced machine learning models during the internship.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision
# The decision is to identify which webpages should be prioritized for SEO optimization. Based on the machine learning model's prediction, the SEO team decides whether a webpage requires immediate attention to prevent a decline in its search performance or whether it is performing well enough to continue monitoring without any immediate changes.
# Action
# Once the decision is made, the SEO team takes appropriate action. For webpages predicted to decline, they may update the content, improve keyword optimization, fix technical SEO issues, strengthen internal linking, and optimize page titles and meta descriptions. These actions are intended to improve the page's visibility in search engines and prevent a loss of organic traffic.
# Cost of a Wrong Recommendation
# A wrong recommendation can have different consequences depending on the type of error. If the model incorrectly predicts that a healthy webpage will decline (false positive), the SEO team may spend unnecessary time and resources optimizing a page that did not need attention. On the other hand, if the model predicts that a webpage is healthy when it is actually going to decline (false negative), the page may lose search rankings, experience a drop in organic traffic, and potentially reduce user engagement or business opportunities. Therefore, accurate predictions are important for making effective SEO decisions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

declining = (df["trend_direction"] == "down").mean() * 100

print("Declining pages:", round(declining,2),"%")
# Out:
# Rows: 30000
# Columns: 44
# Declining pages: 54.21 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project aims to support SEO decision-making by identifying webpages that may deserve review. The model does not prove that refreshing a page will improve rankings or traffic. Instead, it provides a ranked recommendation based on historical evidence, while the final decision remains with a human reviewer.

# %% [markdown]
# ## Self-check
#
# ✅ Selected a predefined lane.
# ✅ Defined the research question.
# ✅ Identified the unit of analysis.
# ✅ Explained the output.
# ✅ Described the decision and action.
# ✅ Explained the cost of incorrect recommendations.
# ✅ Explained why machine learning is appropriate.
# ⏳ Added real statistics from the starter dataset after running the notebook.
